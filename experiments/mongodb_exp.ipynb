# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://khanaliahmad296_db_user:xYlobeksVlAHASxx@ecom-pydantic.cxrh2dz.mongodb.net/?appName=ecom-pydantic")

# %%
db=client["test_ecom_db"]

collection=db["products"]

print("Connected to mongo DB...")
# Out:
# Connected to mongo DB...

# %%
product={
    "name":"Men Casual Shirt",
    "price":999,
    "category":"men"
}

collection.insert_one(product)


#collection.insert_many(product) for many products
# Out:
# InsertOneResult(ObjectId('6a6560e91231abcfb7ba941d'), acknowledged=True)

# %%
all_products=collection.find()

for p in all_products:
    print(p)


'''
product=collection.find_one({"name":"Jeans"})

text to NoSQL'''
# Out:
# {'_id': ObjectId('6a6560e91231abcfb7ba941d'), 'name': 'Men Casual Shirt', 'price': 1399, 'category': 'men'}
# '\nproduct=collection.find_one({"name":"Jeans"})\n\ntext to NoSQL'

# %% [markdown]
# Update

# %%
collection.update_one(
    {"name":"Men Casual Shirt"},
    {"$set":{"price":1399 }}

)

print("Product Updated!!")
# Out:
# Product Updated!!

# %% [markdown]
# DELETE

# %%
#collection.delete_one({"key":value}) for one product
#collection.delete_many() for all products

# %% [markdown]
# Pydantic AI

# %%
import nest_asyncio
nest_asyncio.apply()

import os
from dotenv import load_dotenv
from pydantic_ai import Agent

# %%
load_dotenv()
# Out:
# True

# %%
basic_agent=Agent("groq:llama-3.1-8b-instant")

response=basic_agent.run_sync("why is the sky blue? give response in a funny way")
print("response:", response.output)
# Out:
# response: You want to know the "real" reason the sky is blue? Well, let me tell you a tale of tiny, tiny particles called photons (pronounced "pho-tons" – sounds cool, right?).
#
# See, these little guys are like superheroes, flying around in the atmosphere, saving the day one photon at a time. But here's the thing: they're not just any superheroes – they're tiny blue- ray-bathing, sky-collecting, photon-astic heroes!
#
# When sunlight hits the Earth's atmosphere, these photons start bouncing around like they're in a game of cosmic bumper cars. And the reason the sky looks blue is because they're all, like, "Hey, I've got a blue light, I've got a blue light, WATCH THIS – *poof* – blue light!" (Imagine tiny photon karate moves.)
#
# In other words, our eyes see the blue light because it's the shortest (and therefore, brightest) wavelength of the visible spectrum. It's like our eyes are saying, "Ooh, look – the sky is wearing blue skinny jeans – it's so cool!"
#
# ...

# %% [markdown]
# SETUP LOG FIRE

# %%
# !logfire auth
# Out:
# You are already logged in. (Your credentials are stored in C:\Users\khana\.logfire\default.toml)
# If you would like to log in using a different account, use the --region argument:
# logfire --region <region> auth

# %%
# !logfire projects use ecommerce-pydantic-ai
# Out:
# Project configured successfully. You will be able to view it at: https://logfire-eu.pydantic.dev/khanaliahmad296/ecommerce-pydantic-ai

# %%
import logfire

logfire.configure()
logfire.instrument_pydantic_ai()
# Out:
# Logfire project URL: https://logfire-eu.pydantic.dev/khanaliahmad296/ecommerce-pydantic-ai

# %%
pirate_agent=Agent(
    name="Captain Khan",
    description="A great navy captain",
    model="groq:llama-3.3-70b-versatile",
    system_prompt=("You are a navy ship captain,who is on a mission to find one peice, you must answer every question like the chief of naval staff. Never drop your character")
)

# %%
pirate_agent
# Out:
# Agent(model=GroqModel(), name='Captain Khan', end_strategy='graceful', model_settings=None, output_type=<class 'str'>)

# %%
response =pirate_agent.run_sync("Explain how to get food and survive on ship. Anser in one short sentence")

print("Pirate Agent Answer: ", response.output)
# Out:
# 20:12:14.673 Captain Khan run
# 20:12:14.677   chat llama-3.3-70b-versatile
# Pirate Agent Answer:  All crew members are expected to adhere to the galley's scheduled meal times and ration distributions to ensure sustenance and survival during our high-priority mission to find One Piece.
